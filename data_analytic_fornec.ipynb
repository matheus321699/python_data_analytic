# %%
import pandas as pd
import matplotlib.pyplot as plt

table = pd.read_excel('data_base/gastos_trimestrais_fornecedores.xlsx')
table
# Out:
#   Nome do Fornecedor                  Descrição  Q1 (R$)  Q2 (R$)  Q3 (R$)  \
# 0       Fornecedor A    Materiais de Escritório     5000     6000     4500
# 1       Fornecedor B             Serviços de TI    10000    12000    11500
# 2       Fornecedor C       Consultoria Jurídica     3000     3500     4000
# 3       Fornecedor D  Equipamentos de Segurança     8000     7500     8200
# 4       Fornecedor E    Marketing e Publicidade    12000    13000    12500
#
#    Q4 (R$)  Total Anual (R$)
# 0     5500             21000
# 1    13000             46500
# 2     3800             14300
# 3     7800             31500
# 4    14000             51500

# %%
plt.figure(figsize=(12,6))
table = table.dropna()
grafico_de_barras = plt.bar(table['Descrição'].astype(str), table['Total Anual (R$)'], color='blue')
plt.bar_label(grafico_de_barras, fmt="%.01f", size=10, label_type="edge")
plt.xlabel('Fornecedores')
plt.title('Despesas fornecedores no Primeiro Trimestre de 2024')
plt.show()
